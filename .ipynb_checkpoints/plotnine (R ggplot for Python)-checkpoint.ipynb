# %% [markdown]
# # R's ggplot2 package vs Python's plotnine module

# %%
import pandas as pd
import numpy as np

# %%
from plotnine import *
from plotnine.data import *
# Out:
# /home/drkhurram/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ### From Website: http://pltn.ca/plotnine-superior-python-ggplot/

# %%
ggplot(mtcars, aes(x="hp", y="wt", color="mpg")) + geom_point() + \
facet_wrap("~cyl") + theme_bw() 

# Line 1: 
    # ggplot() - Replace data=mtcars in R with mtcars in Python, i.e. here data is only a positional and not keyword argument
    # aes() - Replace x=hp in R with x="hp" in Python, i.e. add quotes around variable names

# Line 2: facet_wrap() - Replace ".~cyl" in R with "~cyl" in Python, i.e. remove dot
# Out:
# <ggplot: (-9223363288561801405)>

# %% [markdown]
# ### From Book: R in Action - 2nd Ed - Robert Kabacoff (2015)

# %%
mtcars.head()
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
# #### Figure 19.1 Scatterplot of automobile weight by mileage

# %%
ggplot(mtcars, aes(x="wt", y="mpg")) + \
geom_point() + \
labs(title="Automobile Data", x="Weight", y="Miles Per Gallon")
# Out:
# <ggplot: (8748284017391)>

# %% [markdown]
# #### Figure 19.2 Scatterplot of automobile weight by gas mileage, with a superimposed line of best fit and 95% confidence region

# %%
ggplot(mtcars, aes(x="wt", y="mpg")) + \
geom_point(color="blue", size=2) + \
geom_smooth(method="lm", color="red", linetype="dashed") + \
labs(title="Automobile Data", x="Weight", y="Miles Per Gallon")
# Line 3: geom_smooth() - Replace linetype=2 in R with linetype="dashed" in Python
# Out:
# <ggplot: (8748292974421)>

# %%
mtcars.head()
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
# You can see both grouping and faceting with the mtcars data frame. First, transform the am, vs, and cyl variables into factors:
# mtcars$am <- factor(mtcars$am, levels=c(0,1), labels=c("Automatic", "Manual"))
# mtcars$vs <- factor(mtcars$vs, levels=c(0,1), labels=c("V-Engine", "Straight Engine"))
# mtcars$cyl <- factor(mtcars$cyl)

# %%
mtcars['am'] = mtcars['am'].astype('category')
# change the type of data in mtcars["am"] to CategoricalDtype
mtcars['am'] = mtcars['am'].cat.rename_categories(["Automatic", "Manual"])
# replace categorical levels 0 and 1 with labels "Automatic" and "Manual"

mtcars['vs'] = mtcars['vs'].astype('category')
# change the type of data in mtcars["vs"] to CategoricalDtype
mtcars['vs'] = mtcars['vs'].cat.rename_categories(["V-Engine", "Straight Engine"])
# replace categorical levels 0 and 1 with labels "V-Engine" and "Straight Engine"

mtcars['cyl'] = mtcars['cyl'].astype('category')
# change the type of data in mtcars["cyl"] to CategoricalDtype

# %%
mtcars.head()
# Out:
#                 name   mpg cyl   disp   hp  drat     wt   qsec  \
# 0          Mazda RX4  21.0   6  160.0  110  3.90  2.620  16.46
# 1      Mazda RX4 Wag  21.0   6  160.0  110  3.90  2.875  17.02
# 2         Datsun 710  22.8   4  108.0   93  3.85  2.320  18.61
# 3     Hornet 4 Drive  21.4   6  258.0  110  3.08  3.215  19.44
# 4  Hornet Sportabout  18.7   8  360.0  175  3.15  3.440  17.02
#
#                 vs         am  gear  carb
# 0         V-Engine     Manual     4     4
# 1         V-Engine     Manual     4     4
# 2  Straight Engine     Manual     4     1
# 3  Straight Engine  Automatic     3     1
# 4         V-Engine  Automatic     3     2

# %%
type(mtcars["name"]) 
# The function type() returns the type of the data structure (which is pandas "Series")
# Out:
# pandas.core.series.Series

# %%
mtcars["name"].dtype 
# The pandas Series method dtype returns the type of the data stored in the data structure ("Object")
# Out:
# dtype('O')

# %%
mtcars["cyl"].dtype
# Out:
# CategoricalDtype(categories=[4, 6, 8], ordered=False)

# %% [markdown]
# #### Figure 19.3 A scatterplot showing the relationship between horsepower and gas mileage separately for transmission and engine type. The number of cylinders in each automobile engine is represented by both shape and color.

# %%
ggplot(mtcars, aes(x="hp", y="mpg",
shape="cyl", color="cyl")) + \
geom_point(size=3) + \
facet_grid("am~vs") + \
labs(title="Automobile Data by Engine Type", x="Horsepower", y="Miles Per Gallon")
# Line 4: facet_grid() - Replace am~vs in R with "am~vs" in Python, i.e. add quotes around faceting variables
# Out:
# <ggplot: (8748341254506)>

# %%
singer = pd.read_csv("singer.csv")

# %%
singer.head()
# Out:
#    height voice.part
# 0      64  Soprano 1
# 1      62  Soprano 1
# 2      66  Soprano 1
# 3      65  Soprano 1
# 4      60  Soprano 1

# %%
singer.columns = ["height", "voice"] 
# Rename columns to remove dot in the column voice.part as Python plotnine ggplot cannot handle it.

# %%
singer.head()
# Out:
#    height      voice
# 0      64  Soprano 1
# 1      62  Soprano 1
# 2      66  Soprano 1
# 3      65  Soprano 1
# 4      60  Soprano 1

# %% [markdown]
# #### Figure 19.4 Histogram of singer heights

# %%
ggplot(singer, aes(x="height")) + geom_histogram(bins=20)
# Out:
# <ggplot: (8748278547860)>

# %% [markdown]
# #### Figure 19.5 Box plot of singer heights by voice part

# %%
ggplot(singer, aes(x="voice", y="height")) + geom_boxplot()
# Out:
# <ggplot: (-9223363288576252307)>

# %%
Salaries = pd.read_csv("Salaries.csv")

# %% [markdown]
# #### Figure 19.6 Notched box plots with superimposed points describing the salaries of college professors by rank. A rug plot is provided on the vertical axis.

# %%
ggplot(Salaries, aes(x="rank", y="salary")) + \
geom_boxplot(fill="cornflowerblue", \
color="black", notch=True) + \
geom_point(position="jitter", size=0.5, color="blue", alpha=.5) + \
geom_rug(sides="l", color="black")
# Out:
# <ggplot: (-9223363288576328097)>

# %% [markdown]
# #### Figure 19.7 A combined violin and box plot graph of singer heights by voice part

# %%
ggplot(singer, aes(x="voice", y="height")) + \
geom_violin(fill="lightblue") + \
geom_boxplot(fill="lightgreen", width=.2)
# Out:
# <ggplot: (8748279750478)>

# %% [markdown]
# #### Figure 19.8 Density plots of university salaries, grouped by academic rank

# %%
ggplot(Salaries, aes(x="salary", fill="rank")) + \
geom_density(alpha=.3)
# Out:
# <ggplot: (8748278329706)>

# %%
Salaries.head()
# Out:
#        rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      Prof          B             19           18  Male  139750
# 1      Prof          B             20           16  Male  173200
# 2  AsstProf          B              4            3  Male   79750
# 3      Prof          B             45           39  Male  115000
# 4      Prof          B             40           41  Male  141500

# %%
ggplot(Salaries, aes(x="yrs.since.phd", y="salary", color="rank", shape="sex")) + geom_point()
# Out:
# <ggplot: (-9223363288576465141)>

# %% [markdown]
# #### Figure 19.10 Three versions of a grouped bar chart. Each displays the number of professors by academic rank and sex.

# %%
ggplot(Salaries, aes(x="rank", fill="sex")) + \
geom_bar(position="stack") + labs(title='position="stack"')
# Out:
# <ggplot: (8748278299200)>

# %%
ggplot(Salaries, aes(x="rank", fill="sex")) + \
geom_bar(position="dodge") + labs(title='position="dodge"')
# Out:
# <ggplot: (-9223363288576536025)>

# %%
ggplot(Salaries, aes(x="rank", fill="sex")) + \
geom_bar(position="fill") + labs(title='position="fill"', y="Proportion")
# Out:
# <ggplot: (8748278516614)>

# %%
ggplot(singer, aes(x='height')) + \
geom_histogram(bins=10) + \
facet_wrap("~voice", nrow=4)
# Line 2: geom_histogram() - Add bins=10 in Python to avoid warning display
# Line 3: facet_wrap() - Replace ".~voice" in R with "~voice" in Python
# Out:
# <ggplot: (-9223363288575042665)>

# %%
ggplot(Salaries, aes(x="yrs.since.phd", y="salary", color="rank", shape="rank")) + geom_point() + facet_grid(".~sex")
# For facet_grid(), the dot is needed in Python just like R
# Out:
# <ggplot: (-9223363288576474052)>

# %%
ggplot(singer, aes(x="height", fill="voice")) + \
geom_density() + \
facet_grid("voice~.")
# Out:
# <ggplot: (8748278605604)>

# %%
ggplot(Salaries, aes(x="yrs.since.phd", y="salary")) + \
geom_smooth() + geom_point()
# Out:
# /home/drkhurram/anaconda3/lib/python3.6/site-packages/plotnine/stats/smoothers.py:150: UserWarning: Confidence intervals are not yet implementedfor lowess smoothings.
#   warnings.warn("Confidence intervals are not yet implemented"
# <ggplot: (-9223363288576274302)>

# %%
# ggplot(Salaries, aes(x="yrs.since.phd", y="salary",\
# linetype="sex", shape="sex", color="sex")) + \
# geom_smooth(method="lm", formula="y~poly(x,2)",\
# se=False, size=1) + \
# geom_point(size=2)

# Line 3: geom_smooth() - method and formula parameters have not yet been implemented

# %%
ggplot(Salaries, aes(x="rank", y="salary", fill="sex")) + \
geom_boxplot() + \
scale_x_discrete(breaks=["AsstProf", "AssocProf", "Prof"],\
labels=["Assistant\nProfessor", "Associate\nProfessor", "Full\nProfessor"]) + \
scale_y_continuous(breaks=[50000, 100000, 150000, 200000],\
labels=["$50K", "$100K", "$150K", "$200K"]) + \
labs(title="Faculty Salary by Rank and Sex", x="", y="")

# Line 3: scale_x_discrete() - Replace c( with [ and ) with ] to make a Python list
# Line 5: scale_y_continuous() - Replace c( with [ and ) with ] to make a Python list
# Out:
# <ggplot: (-9223363288576416403)>

# %%
ggplot(Salaries, aes(x="rank", y="salary", fill="sex")) + \
geom_boxplot() + \
scale_x_discrete(breaks=["AsstProf", "AssocProf", "Prof"],\
labels=["Assistant\nProfessor", "Associate\nProfessor", "Full\nProfessor"]) + \
scale_y_continuous(breaks=[50000, 100000, 150000, 200000],\
labels=["$50K", "$100K", "$150K", "$200K"]) + \
labs(title="Faculty Salary by Rank and Sex", x="", y="", fill="Gender") + \
theme(legend_position=(.23,.7))

# Last Line: theme() - Replace legend.position in R with legend_position in Python
# Also had to change the tuple value from legend_position=(.1,.8) to legend_position=(.23,.7) to get the same position as R
# Out:
# <ggplot: (-9223363288576219967)>

# %%
ggplot(mtcars, aes(x="wt", y="mpg", size="disp")) + \
geom_point(shape="o", color="black", fill="cornsilk") + \
labs(x="Weight", y="Miles Per Gallon", \
title="Bubble Chart", size="Engine Displacement")

# Line 2: geom_point() - Replace shape=21 with shape="o". Other shape options are as follows: 
# d: diamond, h: hexagon, p: pentagon, s: square, v: inverted triangle, x: cross, 
# 1: Y, 2: inverted Y, 3: right Y, 4: left Y, 8: Octagon

# Last Line: Had to replace size="Engine\nDisplacement" with size="Engine Displacement" to avoid overlap on legend
# Out:
# <ggplot: (8748278458681)>

# %%
ggplot(Salaries, aes(x="yrs.since.phd", y="salary", color="rank")) + \
scale_color_manual(values=["orange", "olivedrab", "navy"]) + \
geom_point(size=1)

# Last Line: Had to replace geom_point(size=2) with geom_point(size=1) for equivalent size in R
# Out:
# <ggplot: (-9223363288576339417)>

# %%
ggplot(Salaries, aes(x="yrs.since.phd", y="salary", color="rank")) + \
scale_color_brewer(palette="YlOrRd") + geom_point(size=1)

# Last Line: scale_color_brewer() - Had to replace palette="Set1" with a valid palette name
# Valid names are: ['Blues', 'BuGn', 'BuPu', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 
# 'PuBu', 'PuBuGn', 'PuRd', 'Purples', 'RdPu', 'Reds', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd']
# Out:
# <ggplot: (-9223363288576339312)>

# %%
mytheme = theme(plot_title=element_text(face="bold.italic", size=14, color="brown"),\
axis_title=element_text(face="bold.italic", size=10, color="brown"),\
axis_text=element_text(face="bold", size=9, color="darkblue"),\
panel_background=element_rect(fill="white", color="darkblue"),\
panel_grid_major_y=element_line(color="grey", linetype="solid"),\
panel_grid_minor_y=element_line(color="grey", linetype="dashdot"),\
panel_grid_minor_x=element_blank(), \
legend_position="top")

ggplot(Salaries, aes(x="rank", y="salary", fill="sex")) + \
geom_boxplot() + \
labs(title="Salary by Rank and Sex", x="Rank", y="Salary") + \
mytheme
# Out:
# <ggplot: (-9223363288576409172)>

# %% [markdown]
# p1 = ggplot(Salaries, aes(x="rank")) + geom_bar()
# p2 = ggplot(Salaries, aes(x="sex")) + geom_bar()
# p3 = ggplot(Salaries, aes(x="yrs.since.phd", y="salary")) + geom_point()
#
# grid_arrange(p1, p2, p3, ncol=3)

# %%
# %load_ext rpy2.ipython
# Out:
# /home/drkhurram/anaconda3/lib/python3.6/site-packages/rpy2/ipython/rmagic.py:73: UserWarning: The Python package 'pandas' is stronglyrecommended when using `rpy2.ipython`. Unfortunately it could not be loaded, but at least we found 'numpy'.
#   "but at least we found 'numpy'.")))

# %%
# %%R
# library(ggplot2)
# data(Salaries, package="carData")
# ggplot(data=Salaries, aes(x=yrs.since.phd, y=salary)) +
# geom_smooth() + geom_point()
# Out:
# /home/drkhurram/anaconda3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: `geom_smooth()` using method = 'loess'
#
#   warnings.warn(x, RRuntimeWarning)

# %%
# %%R
# ggplot(data=Salaries, aes(x=yrs.since.phd, y=salary, linetype=sex, shape=sex, color=sex)) +
# geom_smooth(method=lm, formula=y~poly(x,2), se=FALSE, size=1) +
# geom_point(size=2)

# %%
# %%R
# p1 <- ggplot(data=Salaries, aes(x=rank)) + geom_bar()
# p2 <- ggplot(data=Salaries, aes(x=sex)) + geom_bar()
# p3 <- ggplot(data=Salaries, aes(x=yrs.since.phd, y=salary)) + geom_point()
# library(gridExtra)
# grid.arrange(p1, p2, p3, ncol=3)
